# %%
import seaborn as sns
import pandas as pd
# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc


palette = ['#ff3b30', '#4cd964', '#ffcc00', '#007aff', '#5856d6', '#ff9500', '#5ac8fa', '#ff2d55', '#969783']
markers = ['o', '^', '<', 'd', '*', '2']
sns.set_style("ticks")


mpl.rcParams['lines.markersize'] = 6
mpl.rcParams['lines.linewidth'] = 1
rc("font", **{'family': 'serif', 'serif': ['Palatino'], 'size': 16})
rc('text', usetex=True)
plt.style.use("seaborn-v0_8-bright")
import os

# %%
# !pip install phaseportrait
# draw  motivating example
from phaseportrait import PhasePortrait2D
import matplotlib.pyplot as plt
import os
import numpy as np

eq_idx = 'vars2_prog5'

# %%
from numpy import sin, cos
def pred_by_odeformer(x_0, x_1):
    # return 1.0323 * x_1, -0.0077 * (-10.6200 + -342.6321 * x_0)**-1 + -0.8863 * x_0
    return 0.9825 * x_1 + -0.0030 * (-0.5222 + -1 * x_0)**2,  -0.5720 * x_0
def pred_by_act_ode(X0, X1):
    return 10*sin(X1),  4*cos(X0+2)
    # return 2.471633076778672*cos(X1),  -28.092563965581228*sin(X1)
    # return X0**2/(X0 + X1) - 0.05304339958981804*X0/(X0 + X1),         -0.10777048133957601*sin(X0)
    # return 4.5718721727894*cos(X0),    -0.3080974385540054*sin(X1)
    # return 1.5555479508575738*sin(X0) + 0.8498459598902768*sin(X1),    X0
    # return 2.430880570020358,  0.10131705371347152*cos(X0)
    # return  0.12311764326852309*cos(X1) + 0.0014615757564000317/cos(X1)**2,      X1
    # return -0.13164536105462787*cos(X1),       X1
    # return -2.0*X1 + 7.26073676830629*cos(X1),         -12.920930806050803*cos(X0)
    # return 0.7382801840280069*cos(X1),         X0
    # return X0,         X0 + 0.4733372266277909*sin(X0)**2 - 1.262812747788652*sin(X0)*cos(X0)/cos(X1) + 0.5607870702639666*sin(X0) - 0.6882320967092081*sin(X0)/cos(X1) + 0.8440683716819353*cos(X1)
    # return 2.875057222804865*sin(X0) + 3.9977305842105917*cos(X0) + 1.5477508238668314*cos(X1),        -X0 - 13.286673931468583*sin(X0)*sin(X1)**2 - 2.4689800056536084*sin(X0)*sin(X1)*cos(X1) + 3.898947302771246*sin(X0)
    # return X0,         X0 + 0.4733372266277909*sin(X0)**2 - 1.262812747788652*sin(X0)*cos(X0)/cos(X1) + 0.5607870702639666*sin(X0) - 0.6882320967092081*sin(X0)/cos(X1) + 0.8440683716819353*cos(X1)
    # return 4.493159358879518*np.sin(X1),  4.0829992948610752*np.sin(X0)*np.sin(X1)
    # return 2.355666056731998 - 0.33656295598352154/np.cos(X1),    -0.45960987494496275*np.sin(X1)
    

    # return 0.00049728096303412176*x_0*x_1 + 0.34182666028141486*x_0 + x_1 + 0.008308485714638416,  -4.627633458204109*x_0 - x_1


fig=plt.figure(figsize=(4,3))
Oscillator1 = PhasePortrait2D(pred_by_act_ode, Range=[[-4,4], [-1.5, 1.5]], MeshDim=21, Title="",
                              xlabel=r"$x_1$", ylabel=r"$x_2$", fig=fig, )
fig, ax=Oscillator1.plot(color="grey")
fig.suptitle("Predicted ODE $\phi_1=(10\sin(x_2),  4\cos(x_1+2))$", fontsize=13)
# plt.show()

fname = os.path.join(eq_idx+"_phase.pipe1.pdf")
plt.savefig(fname, bbox_inches='tight', pad_inches=0)
plt.close()

# %%
def pred_by_act_ode(X0, X1):
    return 0.9*sin(X1),         X0+3
fig=plt.figure(figsize=(4,3))
Oscillator1 = PhasePortrait2D(pred_by_act_ode, Range=[[-4,4], [-1.5, 1.5]], MeshDim=21, Title="",
                              xlabel=r"$x_1$", ylabel=r"$x_2$", fig=fig, )
fig, ax=Oscillator1.plot(color="grey")
fig.suptitle("Predicted ODE $\phi_2=(0.9\sin(x_2), x_1+3)$", fontsize=13)
sns.lineplot()

fname = os.path.join(eq_idx+"_phase.pipe2.pdf")
plt.savefig(fname, bbox_inches='tight', pad_inches=0)
plt.close()

# %%
def pred_by_act_ode(x_0, x_1):
    return 1.04*x_1,  -0.02-0.77*x_0
fig=plt.figure(figsize=(6,4))
Oscillator1 = PhasePortrait2D(pred_by_act_ode, Range=[[-4,4], [-1.5, 1.5]], MeshDim=21, Title="",
                              xlabel=r"$x_1$", ylabel=r"$x_2$", fig=fig, )
fig, ax=Oscillator1.plot(color="grey")
fig.suptitle("Candidate ODE $\phi_3=(1.04*x_2, -0.02 -0.77 x_1)$", fontsize=14)
sns.lineplot()

fname = os.path.join(eq_idx+"_phase.pipe3.pdf")
plt.savefig(fname, bbox_inches='tight', pad_inches=0)
plt.close()

# %%
x_train = [
    [0.9136266440462718, 0.022132008552811118],
    [0.9138124833432186, 0.014998883742367863],
    [0.9139269162411766, 0.007864932838087882],
    [0.9139699364369154, 0.0007305488268623019],
    [0.9139415415617053, -0.006403875386865158],
    [0.9138417368100361, -0.013537942324328983],
    [0.9136705463206712, -0.02067123723834982],
    [0.9134279780590836, -0.0278033734280455],
    [0.9131140408413311, -0.034933967061717405],
    [0.9127287477835669, -0.04206263252577112],
    [0.9122721163020396, -0.04918898242471633],
    [0.9117441681130928, -0.05631262758116693],
    [0.9111449292331655, -0.06343317703584102],
    [0.9104744299787919, -0.07055023804756072],
    [0.9097327049666016, -0.07766341609325252],
    [0.9089197931133194, -0.0847723148679469],
    [0.9080357376357651, -0.09187653628477857],
    [0.9070805860508541, -0.09897568047498644],
    [0.9060543901755969, -0.10606934578791352],
    [0.9049572061270993, -0.11315712879100706],
    [0.9037890943225624, -0.12023862426981838],
    [0.9025501194792824, -0.12731342522800304],
    [0.9012403506146509, -0.13438112288732074],
    [0.8998598610461548, -0.14144130668763533],
    [0.8984087283913761, -0.1484935642869149],
    [0.8968870345679921, -0.15553748156123154],
    [0.8952948657937756, -0.16257264260476167],
    [0.8936323125865941, -0.16959862972978584],
    [0.891899469764411, -0.17661502346668878],
    [0.8900964364452846, -0.18362140256395915],
    [0.8882233160473685, -0.1906173439881902],
    [0.8862802162889115, -0.19760242292407898],
    [0.8842672491882579, -0.2045762127744269],
    [0.8821845310638471, -0.21153828516013945],
    [0.8800321825342136, -0.21848820992022633],
]

# %%
x_train=np.array(x_train)
x_train.shape
# Out:
# (1000, 2)

# %%
def pred_by_odeformer(x_0, x_1):
    return 1.0403 * x_1, -0.0202 + -0.7705 * x_0

fig=plt.figure(figsize=(6,4))
Oscillator1 = PhasePortrait2D(pred_by_odeformer, Range=[[-4,4], [-1.5, 1.5]], MeshDim=21, Title="",
                              xlabel=r"$x_1$", ylabel=r"$x_2$", fig=fig, )
fig,ax=Oscillator1.plot(color="grey")
fig.suptitle("Predicted ODE (by ODEFormer)", fontsize=14)
sns.lineplot()

sns.scatterplot(x=x_train[:600:10,0], y=x_train[:600:10,1],  s=10, legend=False, color=palette[3])

i=0
string="$\mathbf{x}({"+str(i)+"})$"
plt.text(x_train[i:i+1,0]-0., x_train[i:i+1,1]+0., string, fontsize=16,color=palette[3], ha='left')
i=100
string="$\mathbf{x}(t_{"+str(i)+"})$"
plt.text(x_train[i:i+1,0]+0.2, x_train[i:i+1,1]-0.1, string, fontsize=16,color=palette[3], ha='left')
i=200
string="$\mathbf{x}(t_{"+str(i)+"})$"
plt.text(x_train[i:i+1,0]+0.1, x_train[i:i+1,1]-0.25, string, fontsize=16,color=palette[3], ha="center")
i=300
string="$\mathbf{x}(t_{"+str(i)+"})$"
plt.text(x_train[i:i+1,0]-0.2, x_train[i:i+1,1], string, fontsize=16,color=palette[3], ha="right")

i=400
string="$\mathbf{x}(t_{"+str(i)+"})$"
plt.text(x_train[i:i+1,0], x_train[i:i+1,1]+0.05, string, fontsize=16,color=palette[3], ha="right")


i=500
string="$\mathbf{x}(t_{"+str(i)+"})$"
plt.text(x_train[i:i+1,0], x_train[i:i+1,1]+0.15, string, fontsize=16,color=palette[3], ha="center")

i=600
string="$\mathbf{x}(t_{"+str(i)+"})$"
plt.text(x_train[i:i+1,0], x_train[i:i+1,1]+0.15, string, fontsize=16,color=palette[3], ha="left")


fname = os.path.join(eq_idx+"_phase.ode_former.pdf")
plt.savefig(fname, bbox_inches='tight', pad_inches=0)
plt.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 7
#       4 fig=plt.figure(figsize=(6,4))
#       5 Oscillator1 = PhasePortrait2D(pred_by_odeformer, Range=[[-4,4], [-1.5, 1.5]], MeshDim=21, Title="",
#       6                               xlabel=r"$x_1$", ylabel=r"$x_2$", fig=fig, )
# ----> 7 fig,ax=Oscillator1.plot(color="grey")
#       8 fig.suptitle("Predicted ODE (by ODEFormer)", fontsize=14)
#       9 sns.lineplot()
#
# File ~/PycharmProjects/act_ode/src/phaseportrait/phaseportrait/PhasePortrait2D.py:154, in PhasePortrait2D.plot(self, color, grid)
#     151 if grid is not None:
#     152     self.grid = grid
# --> 154 self.stream = self.draw_plot(color=self.color, grid=grid)
#     156 if hasattr(self, "colorbar_ax"):
#     157     cb = plt.colorbar(mplcm.ScalarMappable(
#     158             norm=self.stream._velocity_normalization(),
# ...

# %%
def ground_truth(x_0, x_1):
    x = [x_0, x_1]
    return x[1], -0.9 * np.sin(x[0])
fig=plt.figure(figsize=(6,4))
            
Oscillator3 = PhasePortrait2D(ground_truth, Range=[[-4,4], [-1.5, 1.5]], MeshDim=21,Title="", xlabel=r"$x_1$", ylabel=r"$x_2$", fig=fig)
fig,ax=Oscillator3.plot(color='Blues')
fig.suptitle("Ground Truth ODE", fontsize=14)
sns.scatterplot(x=x_train[:600:10,0], y=x_train[:600:10,1], s=10, legend=False, color=palette[3])
i=0
string="$\mathbf{x}({"+str(i)+"})$"
plt.text(x_train[i:i+1,0]-0., x_train[i:i+1,1]+0., string, fontsize=16,color=palette[3], ha='left')
i=100
string="$\mathbf{x}(t_{"+str(i)+"})$"
plt.text(x_train[i:i+1,0]+0.2, x_train[i:i+1,1]-0.1, string, fontsize=16,color=palette[3], ha='left')
i=200
string="$\mathbf{x}(t_{"+str(i)+"})$"
plt.text(x_train[i:i+1,0]+0.1, x_train[i:i+1,1]-0.25, string, fontsize=16,color=palette[3], ha="center")
i=300
string="$\mathbf{x}(t_{"+str(i)+"})$"
plt.text(x_train[i:i+1,0]-0.2, x_train[i:i+1,1], string, fontsize=16,color=palette[3], ha="right")

i=400
string="$\mathbf{x}(t_{"+str(i)+"})$"
plt.text(x_train[i:i+1,0], x_train[i:i+1,1]+0.05, string, fontsize=16,color=palette[3], ha="right")


i=500
string="$\mathbf{x}(t_{"+str(i)+"})$"
plt.text(x_train[i:i+1,0], x_train[i:i+1,1]+0.15, string, fontsize=16,color=palette[3], ha="center")

i=600
string="$\mathbf{x}(t_{"+str(i)+"})$"
plt.text(x_train[i:i+1,0], x_train[i:i+1,1]+0.15, string, fontsize=16,color=palette[3], ha="left")

plt.show()
fname = os.path.join(eq_idx+"_phase.correct.pdf")
plt.savefig(fname, bbox_inches='tight', pad_inches=0)
plt.close()

# %%
def ground_truth(x_0, x_1):
    x = [x_0, x_1]
    return x[1], -0.9 * np.sin(x[0])

# %%
fig=plt.figure(figsize=(4,3))    
Oscillator3 = PhasePortrait2D(ground_truth, Range=[[-4,4], [-1.5, 1.5]], MeshDim=21,Title="", xlabel=r"$x_1$", ylabel=r"$x_2$", fig=fig)


fig, ax=Oscillator3.plot(color='Greys')


mu_x, mu_y = 3, 0  # Mean of the Gaussian distribution
sigma_x, sigma_y = 0.8, 0.6  # Standard deviation of the Gaussian distribution
size = 100  # Size of the grid

# Create a grid of x and y values within the specified range
x = np.linspace(-4, 4, size)
y = np.linspace(-1.5, 1.5, size)
X, Y = np.meshgrid(x, y)
threshold=0.01
# Plot the discretized Gaussian heatmap
# Compute the Gaussian distribution at each point on the grid
Z = (1 / (2 * np.pi * sigma_x * sigma_y)) * np.exp(-((X - mu_x)**2 / (2 * sigma_x**2) + (Y - mu_y)**2 / (2 * sigma_y**2)))
x_pts, y_pts = np.where(Z > threshold)
ax.scatter(X[x_pts, y_pts], Y[x_pts, y_pts], c=Z[x_pts, y_pts], cmap='Blues', s=10, marker='.')
# fig.set_size_inches(5, 3.5)
# fig.suptitle("Ground Truth ODE", fontsize=14)
# plt.show()
fname = os.path.join(eq_idx+"_phase.density.pdf")
plt.savefig(fname, bbox_inches='tight', pad_inches=0)
plt.close()
